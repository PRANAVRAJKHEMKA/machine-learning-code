# %%
import torch

# %%
x=torch.arange(6,dtype=torch.float32).reshape(2,3)

# %%
x
# Out:
# tensor([[0., 1., 2.],
#         [3., 4., 5.]])

# %%
y=x.clone()

# %%
y
# Out:
# tensor([[0., 1., 2.],
#         [3., 4., 5.]])

# %%
x+y
# Out:
# tensor([[ 0.,  2.,  4.],
#         [ 6.,  8., 10.]])

# %%
x*y #   hadamard product
# Out:
# tensor([[ 0.,  1.,  4.],
#         [ 9., 16., 25.]])

# %%
a=2
a+x,a*x
# Out:
# (tensor([[2., 3., 4.],
#          [5., 6., 7.]]),
#  tensor([[ 0.,  2.,  4.],
#          [ 6.,  8., 10.]]))
