# %%
import torch
x=torch.arange(3)
y=torch.tensor([3,4,5])

# %%
torch.dot(x,y)
# Out:
# tensor(14)

# %%
a=x*y

# %%
a
# Out:
# tensor([ 0,  4, 10])

# %%
a.sum()
# Out:
# tensor(14)

# %%
torch.sum(x*y)
# Out:
# tensor(14)
