# %%
import torch
u=torch.tensor([3.,-4.])
torch.norm(u)
# Out:
# tensor(5.)

# %%
torch.abs(u).sum()     #Manhattan Distance
# Out:
# tensor(7.)

# %%
torch.norm(torch.ones(4,9))
# Out:
# tensor(6.)
