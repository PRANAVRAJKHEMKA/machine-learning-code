# %%
import torch
import numpy as np
def f(x):
    return 3*x**2 - 4*x

# %%
for h in 10.0**np.arange(-1,-6,-1):
    print("h= ",h," numerical value= ",(f(1+h)-f(1))/h)
# Out:
# h=  0.1  numerical value=  2.3000000000000043
# h=  0.01  numerical value=  2.0299999999999763
# h=  0.001  numerical value=  2.002999999999311
# h=  0.0001  numerical value=  2.0002999999979565
# h=  1e-05  numerical value=  2.0000300000155846
