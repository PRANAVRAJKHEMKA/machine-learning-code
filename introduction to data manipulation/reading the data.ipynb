# %%
import os

# %%
data_file="house_tiny.csv"

# %%
print(os.getcwd())
# Out:
# D:\python_main\python_program_files\data

# %%
with open(data_file,'w') as f:
    f.write('''NumRooms,RoofType,Price
NA,NA,127500
2,NA,106000
4,Slate,178100
NA,NA,140000''')

# %%
print(data_file)
# Out:
# house_tiny.csv

# %%
import pandas as pd

# %%
data = pd.read_csv("house_tiny.csv",na_values=["NA"])
print(data)
# Out:
#    NumRooms RoofType   Price
# 0       NaN      NaN  127500
# 1       2.0      NaN  106000
# 2       4.0    Slate  178100
# 3       NaN      NaN  140000

# %%
print(data.dtypes)
# Out:
# NumRooms    float64
# RoofType     object
# Price         int64
# dtype: object

# %%
with open("house_tiny.csv","r") as g:
    print(g.read())
# Out:
# NumRooms,RoofType,Price
# NA,NA,127500
# 2,NA,106000
# 4,Slate,178100
# NA,NA,140000

# %%
print(repr(data["NumRooms"][0]))
# Out:
# np.float64(nan)
